# %%
import requests
import datetime as dt
import pandas as pd
date = dt.date.today().strftime("%d-%m-%Y")
url = "https://api.coingecko.com/api/v3/coins/bitcoin/history"
params = {
    "date": f"{date}",  # Format: DD-MM-YYYY
    "localization": "false"
}
response = requests.get(url, params=params)
data = response.json()
df_price = pd.DataFrame([data['market_data']['current_price']])
df_price['date']=dt.date.today()
df_price
# Out:
#            aed           ars            aud         bch           bdt  \
# 0  393530.4224  1.559608e+08  164830.043294  228.889029  1.309097e+07
#
#             bhd            bmd        bnb            brl  btc  ...        xau  \
# 0  40335.769947  107156.003376  98.083813  579553.244262  1.0  ...  25.213808
#
#             xdr            xlm           xrp        yfi           zar  \
# 0  75007.809335  341158.087121  45414.956964  22.561438  1.861109e+06
#
#             bits         link          sats        date
# 0  999997.791067  6372.336712  9.999978e+07  2025-10-19
#
# [1 rows x 64 columns]
